# %% [markdown]
# # <div class="alert alert-info" role="alert"> <center>TP P4 Modélisation de la réfraction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Le programme ci-dessous permet de calculer l'indice de réfraction n2 du milieur 2 à partir de tes résultats expérimentaux.

# %%
from math import *
print ("Est-ce le bon modèle ?")
i1=[0,10,20,30,40,50,60]
i2=[0,0,0,0,0,0,0]
print( "Quel est l'indice du milieu du rayon incident ?")
n1=float(input("n1="))
for i in range(len(i1)):
	print ('Quand i1 = ',i1[i], 'quelle est la mesure de i2 en degré ?')
	i2[i]=float(input("i2="))
	i1[i]=i1[i]*pi/180
	i2[i]=i2[i]*pi/180
for i in range(1,len(i1)):
	n2= n1*i2[i]/i1[i]
	print ('Pour le couple de mesure n°',i,'la valeur de n2 est :',n2)
print ( "Tu te charges d'ajuster le nombre de chiffres significatifs")
print("Alors ! Les résultats sont-ils satisfaisants ?")
